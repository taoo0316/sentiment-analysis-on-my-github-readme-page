# %%
# !pip install HanLP
# Out:
# Collecting HanLP
#   Downloading hanlp-2.1.0b34-py3-none-any.whl (589 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 589.1/589.1 kB 2.7 MB/s eta 0:00:00a 0:00:01
# Collecting hanlp-common>=0.0.13
#   Downloading hanlp_common-0.0.15.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Collecting tokenizers==0.11.6
#   Downloading tokenizers-0.11.6-cp38-cp38-macosx_10_11_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 5.5 MB/s eta 0:00:0000:0100:01
# Collecting hanlp-downloader
#   Downloading hanlp_downloader-0.0.25.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Collecting toposort==1.5
#   Downloading toposort-1.5-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: transformers>=4.1.1 in /opt/anaconda3/lib/python3.8/site-packages (from HanLP) (4.19.2)
# Requirement already satisfied: termcolor in /opt/anaconda3/lib/python3.8/site-packages (from HanLP) (1.1.0)
# Collecting hanlp-trie>=0.0.4
#   Downloading hanlp_trie-0.0.5.tar.gz (6.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.6.0 in /opt/anaconda3/lib/python3.8/site-packages (from HanLP) (1.11.0)
# Collecting pynvml
#   Downloading pynvml-11.4.1-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 2.7 MB/s eta 0:00:00
# Collecting phrasetree
#   Downloading phrasetree-0.0.8.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: typing-extensions in /opt/anaconda3/lib/python3.8/site-packages (from torch>=1.6.0->HanLP) (4.1.1)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/lib/python3.8/site-packages (from transformers>=4.1.1->HanLP) (1.22.3)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.8/site-packages (from transformers>=4.1.1->HanLP) (2.27.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /opt/anaconda3/lib/python3.8/site-packages (from transformers>=4.1.1->HanLP) (0.7.0)
# Requirement already satisfied: filelock in /Users/zwt2000/.local/lib/python3.8/site-packages (from transformers>=4.1.1->HanLP) (3.4.2)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.8/site-packages (from transformers>=4.1.1->HanLP) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.8/site-packages (from transformers>=4.1.1->HanLP) (5.4.1)
# Requirement already satisfied: tqdm>=4.27 in /opt/anaconda3/lib/python3.8/site-packages (from transformers>=4.1.1->HanLP) (4.64.0)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/lib/python3.8/site-packages (from transformers>=4.1.1->HanLP) (2021.4.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->transformers>=4.1.1->HanLP) (2.4.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests->transformers>=4.1.1->HanLP) (1.26.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from requests->transformers>=4.1.1->HanLP) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests->transformers>=4.1.1->HanLP) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests->transformers>=4.1.1->HanLP) (2020.12.5)
# Building wheels for collected packages: hanlp-common, hanlp-trie, hanlp-downloader, phrasetree
#   Building wheel for hanlp-common (setup.py) ... done
#   Created wheel for hanlp-common: filename=hanlp_common-0.0.15-py3-none-any.whl size=29746 sha256=c0549d6908509354ec89968ea426799c299141d0a111bc77b2d00b6b2fba4687
#   Stored in directory: /Users/zwt2000/Library/Caches/pip/wheels/3e/a2/19/b52ffe8d11211a69c1b396ce4864ff1db28b275811c003860c
#   Building wheel for hanlp-trie (setup.py) ... done
#   Created wheel for hanlp-trie: filename=hanlp_trie-0.0.5-py3-none-any.whl size=6817 sha256=2dd56cd85e8e85ea168a731b4588e9692a038429fda4113df6c04f43ae816996
#   Stored in directory: /Users/zwt2000/Library/Caches/pip/wheels/fe/16/e7/5a159248ca2ffe2ddaa644f652d6e2f6b9981c487236172e1f
#   Building wheel for hanlp-downloader (setup.py) ... done
#   Created wheel for hanlp-downloader: filename=hanlp_downloader-0.0.25-py3-none-any.whl size=13746 sha256=28def5faf43f95fe0726c6bd93cbb383bd20c985c173af312ccf5bbba1cbaf9d
#   Stored in directory: /Users/zwt2000/Library/Caches/pip/wheels/0a/c6/56/e77871f72c2a429b1526b79c07d6101f6003e14744202994d6
#   Building wheel for phrasetree (setup.py) ... done
#   Created wheel for phrasetree: filename=phrasetree-0.0.8-py3-none-any.whl size=44218 sha256=59385208b180d0ecc6641d3e034f746951c9fc94bc80fe6a1fb24bcde0710bf4
#   Stored in directory: /Users/zwt2000/Library/Caches/pip/wheels/ca/08/a3/627595d0b24e2810a1b3e1db3868fe2731b276c055aa9a8404
# Successfully built hanlp-common hanlp-trie hanlp-downloader phrasetree
# Installing collected packages: toposort, tokenizers, phrasetree, pynvml, hanlp-common, hanlp-trie, hanlp-downloader, HanLP
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.12.1
#     Uninstalling tokenizers-0.12.1:
#       Successfully uninstalled tokenizers-0.12.1
# Successfully installed HanLP-2.1.0b34 hanlp-common-0.0.15 hanlp-downloader-0.0.25 hanlp-trie-0.0.5 phrasetree-0.0.8 pynvml-11.4.1 tokenizers-0.11.6 toposort-1.5

# %%
# !pip install hanlp_restful
# Out:
# Collecting hanlp_restful
#   Downloading hanlp_restful-0.0.17.tar.gz (8.4 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: hanlp_common in /opt/anaconda3/lib/python3.8/site-packages (from hanlp_restful) (0.0.15)
# Requirement already satisfied: phrasetree in /opt/anaconda3/lib/python3.8/site-packages (from hanlp_common->hanlp_restful) (0.0.8)
# Building wheels for collected packages: hanlp_restful
#   Building wheel for hanlp_restful (setup.py) ... done
#   Created wheel for hanlp_restful: filename=hanlp_restful-0.0.17-py3-none-any.whl size=8245 sha256=541f78514a34a62321572f8b6628e434003f69a6c57a08a5ae1f38558d198e54
#   Stored in directory: /Users/zwt2000/Library/Caches/pip/wheels/95/e4/33/77be3d2b402c510266f8cd66895c53dff437e1b4fd294fbe3e
# Successfully built hanlp_restful
# Installing collected packages: hanlp_restful
# Successfully installed hanlp_restful-0.0.17

# %%
from hanlp_restful import HanLPClient
# Fill in your auth, set language='zh' to use Chinese models
HanLP = HanLPClient('https://hanlp.hankcs.com/api', auth=None, language='mul')
doc = HanLP('In 2021, HanLPv2.1 delivers state-of-the-art multilingual NLP techniques to production environments. ' \
            '2021年、HanLPv2.1は次世代の最先端多言語NLP技術を本番環境に導入します。' \
            '2021年 HanLPv2.1为生产环境带来次世代最先进的多语种NLP技术。')
print(doc)
# Out:
# {
#   "tok": [
#     ["In", "2021", ",", "HanLPv2.1", "delivers", "state-of-the-art", "multilingual", "NLP", "techniques", "to", "production", "environments", "."],
#     ["2021年", "、", "HanLPv2.1", "は", "次", "世代", "の", "最", "先端", "多", "言語", "NLP", "技術", "を", "本番", "環境", "に", "導入", "し", "ます", "。"],
#     ["2021年", "HanLPv2.1", "为", "生产", "环境", "带来", "次世代", "最", "先进", "的", "多语种", "NLP", "技术", "。"]
#   ],
#   "ner": [
#     [["2021", "DATE", 1, 2], ["NLP", "ORG", 7, 8]],
#     [["2021年", "TIME", 0, 1]],
#     [["2021年", "DATE", 0, 1]]
#   ],
#   "srl": [
#     [[["In 2021", "ARGM-TMP", 0, 2], ["delivers", "PRED", 4, 5]]],
#     [],
#     [[["2021年", "ARGM-TMP", 0, 1], ["带来", "PRED", 5, 6]]]
#   ],
#   "sdp/dm": [
#     [[], [[1, "ARG2"]], [], [[5, "ARG1"]], [[0, "ARG1"], [1, "ARG1"]], [], [], [], [[5, "ARG2"], [6, "compound"], [7, "ARG1"], [8, "compound"]], [], [], [[5, "ARG3"], [10, "ARG2"], [11, "compound"]], []],
#     [[], [], [], [], [], [[5, "compound"]], [], [], [], [], [], [], [[12, "compound"]], [], [], [[15, "ARG1"]], [], [], [], [], []],
#     [[], [], [], [], [[3, "ARG2"], [4, "compound"]], [], [], [], [[8, "ARG1"]], [], [], [], [[12, "compound"]], []]
#   ],
#   "sdp/pas": [
#     [[], [[1, "prep_ARG2"]], [], [[5, "verb_ARG1"]], [[0, "conj_ARG1"], [1, "prep_ARG1"], [3, "punct_ARG1"]], [], [], [], [[5, "verb_ARG2"], [6, "adj_ARG1"], [7, "adj_ARG1"], [8, "noun_ARG1"], [10, "prep_ARG1"]], [], [], [[10, "prep_ARG2"], [11, "noun_ARG1"]], []],
#     [[], [], [], [], [], [[5, "noun_ARG1"]], [], [], [[8, "noun_ARG1"]], [], [], [], [[11, "noun_ARG1"], [12, "noun_ARG1"]], [], [], [[15, "adj_ARG1"]], [], [], [[0, "aux_ARG2"], [18, "noun_ARG1"]], [], []],
#     [[], [[1, "adj_ARG1"], [3, "prep_ARG1"]], [], [], [[3, "prep_ARG2"], [4, "noun_ARG1"]], [], [[8, "adj_ARG1"]], [], [[8, "adj_ARG1"]], [], [], [], [[11, "adj_ARG1"], [12, "noun_ARG1"]], []]
#   ],
#   "sdp/psd": [
#     [[], [[5, "TWHEN"]], [], [[5, "ACT-arg"]], [], [[9, "RSTR"]], [[9, "RSTR"]], [[9, "APP"]], [[5, "PAT-arg"]], [], [[12, "RSTR"]], [[5, "ADDR-arg"]], []],
#     [[], [], [], [], [[6, "RSTR"]], [], [], [[9, "RSTR"]], [], [], [], [], [], [], [[16, "RSTR"]], [], [], [[19, "CPHR-arg"]], [], [], []],
#     [[], [], [], [[5, "RSTR"]], [], [], [], [], [], [], [], [[13, "RSTR"]], [], []]
#   ],
#   "con": [
#     ["TOP", [["S", [["PP", [["ADP", ["In"]], ["NP", [["NUM", ["2021"]]]]]], ["PUNCT", [","]], ["NP", [["PROPN", ["HanLPv2.1"]]]], ["VP", [["VERB", ["delivers"]], ["NP", [["ADJ", ["state-of-the-art"]], ["ADJ", ["multilingual"]], ["PROPN", ["NLP"]], ["NOUN", ["techniques"]]]], ["PP", [["ADP", ["to"]], ["NP", [["NOUN", ["production"]], ["NOUN", ["environments"]]]]]]]], ["PUNCT", ["."]]]]]],
#     ["TOP", [["IP", [["IP", [["NP", [["NP", [["NOUN", ["2021年"]]]], ["PUNCT", ["、"]], ["NP", [["NOUN", ["HanLPv2.1"]]]]]], ["ADP", ["は"]], ["IP", [["NP", [["NP", [["DNP", [["NP", [["NOUN", ["次"]], ["NOUN", ["世代"]]]], ["ADP", ["の"]]]], ["NP", [["NOUN", ["最"]], ["NOUN", ["先端"]]]]]], ["ADJP", [["ADJ", ["多"]]]], ["NP", [["NOUN", ["言語"]]]], ["NP", [["NOUN", ["NLP"]], ["NOUN", ["技術"]]]]]], ["ADP", ["を"]], ["IP", [["NP", [["ADJ", ["本番"]], ["NP", [["NOUN", ["環境"]]]]]], ["ADP", ["に"]], ["NP", [["NOUN", ["導入"]], ["VP", [["VERB", ["し"]]]]]]]]]]]], ["AUX", ["ます"]], ["PUNCT", ["。"]]]]]],
#     ["TOP", [["IP", [["NP", [["NP", [["NOUN", ["2021年"]], ["NP", [["PROPN", ["HanLPv2.1"]]]]]], ["VP", [["ADP", ["为"]], ["NP", [["NP", [["NOUN", ["生产"]], ["NOUN", ["环境"]]]], ["VP", [["VERB", ["带来"]], ["NP", [["CP", [["CP", [["IP", [["NP", [["NOUN", ["次世代"]]]], ["VP", [["ADVP", [["ADV", ["最"]]]], ["VP", [["ADJ", ["先进"]]]]]]]], ["ADP", ["的"]]]]]], ["NP", [["NOUN", ["多语种"]]]], ["NP", [["PROPN", ["NLP"]], ["NOUN", ["技术"]]]]]]]]]]]]]], ["VP", [["PUNCT", ["。"]]]]]]]]
#   ],
#   "lem": [
#     ["in", "2021", ",", "hanlpv2.1", "deliver", "state-of-the-art", "multilingual", "NLP", "technique", "to", "production", "environment", "."],
#     ["2021年", "、", "hanlpv2.1", "は", "次", "世代", "の", "最", "先端", "多", "言語", "NLP", "技術", "を", "本番", "環境", "に", "導入", "し", "ます", "。"],
#     ["2021年", "hanlpv2.1", "为", "生产", "环境", "带来", "次世代", "最", "先进", "的", "多语种", "NLP", "技术", "。"]
#   ],
#   "pos": [
#     ["ADP", "NUM", "PUNCT", "PROPN", "VERB", "ADJ", "ADJ", "PROPN", "NOUN", "ADP", "NOUN", "NOUN", "PUNCT"],
#     ["NOUN", "PUNCT", "NOUN", "ADP", "NOUN", "NOUN", "ADP", "NOUN", "NOUN", "ADJ", "NOUN", "NOUN", "NOUN", "ADP", "ADJ", "NOUN", "ADP", "NOUN", "VERB", "AUX", "PUNCT"],
#     ["NOUN", "PROPN", "ADP", "NOUN", "NOUN", "VERB", "NOUN", "ADV", "ADJ", "ADP", "NOUN", "PROPN", "NOUN", "PUNCT"]
#   ],
#   "fea": [
#     ["_", "NumType=Card", "_", "_", "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin", "_", "Degree=Pos", "Number=Sing", "Number=Plur", "_", "Number=Sing", "Number=Plur", "_"],
#     ["_", "_", "_", "_", "_", "_", "_", "_", "_", "_", "_", "_", "_", "_", "_", "_", "_", "_", "_", "_", "_"],
#     ["_", "_", "_", "_", "_", "_", "_", "_", "_", "_", "_", "_", "_", "_"]
#   ],
#   "dep": [
#     [[2, "case"], [5, "obl"], [2, "punct"], [5, "nsubj"], [0, "root"], [9, "amod"], [9, "amod"], [9, "compound"], [5, "obj"], [12, "case"], [12, "compound"], [5, "obl"], [5, "punct"]],
#     [[19, "obl"], [1, "punct"], [1, "nmod"], [3, "case"], [6, "compound"], [9, "nmod"], [6, "case"], [9, "compound"], [13, "nmod"], [13, "amod"], [13, "nmod"], [13, "compound"], [19, "obj"], [13, "case"], [16, "amod"], [19, "obl"], [16, "case"], [19, "obj"], [0, "root"], [19, "aux"], [19, "punct"]],
#     [[6, "obl"], [1, "flat"], [5, "case"], [5, "nmod"], [6, "obl"], [0, "root"], [9, "advmod"], [9, "advmod"], [6, "xcomp"], [9, "mark:rel"], [13, "nmod"], [13, "nmod"], [6, "obj"], [6, "punct"]]
#   ]
# }

# %%
doc.pretty_print()
# Out:
# <div style="display: table; line-height: 128%;"><pre style="display: table-cell; font-family: SFMono-Regular,Menlo,Monaco,Consolas,Liberation Mono,Courier New,monospace; white-space: nowrap;">Dep&nbsp;Tree&nbsp;&nbsp;&nbsp;<br>──────────&nbsp;<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;┌─►&nbsp;<br>&nbsp;&nbsp;&nbsp;&nbsp;┌─►├──&nbsp;<br>&nbsp;&nbsp;&nbsp;&nbsp;│&nbsp;&nbsp;└─►&nbsp;<br>&nbsp;&nbsp;&nbsp;&nbsp;│&nbsp;&nbsp;┌─►&nbsp;<br>┌┬┬─┴──┴──&nbsp;<br>│││&nbsp;&nbsp;┌───►&nbsp;<br>│││&nbsp;&nbsp;│┌──►&nbsp;<br>│││&nbsp;&nbsp;││┌─►&nbsp;<br>││└─►└┴┴──&nbsp;<br>││&nbsp;&nbsp;&nbsp;&nbsp;┌──►&nbsp;<br>││&nbsp;&nbsp;&nbsp;&nbsp;│┌─►&nbsp;<br>│└───►└┴──&nbsp;<br>└────────►&nbsp;</pre><pre style="display: table-cell; font-family: SFMono-Regular,Menlo,Monaco,Consolas,Liberation Mono,Courier New,monospace; white-space: nowrap;">Token&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>────────────────&nbsp;<br>In&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>2021&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>,&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>HanLPv2.1&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>delivers&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>state-of-the-art&nbsp;<br>multilingual&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>NLP&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>techniques&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>to&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>production&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>environments&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>.&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</pre><pre style="display: table-cell; font-family: SFMono-Regular,Menlo,Monaco,Consolas,Liberation Mono,Courier New,monospace; white-space: nowrap;">Relation&nbsp;<br>────────&nbsp;<br>case&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>obl&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>punct&nbsp;&nbsp;&nbsp;&nbsp;<br>nsubj&nbsp;&nbsp;&nbsp;&nbsp;<br>root&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>amod&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>amod&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>compound&nbsp;<br>obj&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>case&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>compound&nbsp;<br>obl&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>punct&nbsp;&nbsp;&nbsp;&nbsp;</pre><pre style="display: table-cell; font-family: SFMono-Regular,Menlo,Monaco,Consolas,Liberation Mono,Courier New,monospace; white-space: nowrap;">Lemma&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>────────────────&nbsp;<br>in&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>2021&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>,&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>hanlpv2.1&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>deliver&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>state-of-the-art&nbsp;<br>multilingual&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>NLP&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>technique&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>to&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>production&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>environment&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>.&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</pre><pre style="display: table-cell; font-family: SFMono-Regular,Menlo,Monaco,Consolas,Liberation Mono,Courier New,monospace; white-space: nowrap;">PoS&nbsp;&nbsp;&nbsp;<br>─────&nbsp;<br>ADP&nbsp;&nbsp;&nbsp;<br>NUM&nbsp;&nbsp;&nbsp;<br>PUNCT&nbsp;<br>PROPN&nbsp;<br>VERB&nbsp;&nbsp;<br>ADJ&nbsp; ...
